# %%
import reporting.services.chart.base_chart
import reporting.services.simulator.base_sim
import reporting.services.chart.tsda_chart
import reporting.services.simulator.tsda_sim

# %% [markdown]
# # Weekly Report

# %%
chart = reporting.services.chart.base_chart.BaseChart('Class Attendance Weekly Report', 'Week', 'Attendance%')
X,Y = reporting.services.simulator.base_sim.BaseSimulator(7).generate()
chart.set_data(x=X, y=Y)
chart.plot()

# %% [markdown]
# # Time Series Chart

# %%
chart = reporting.services.chart.tsda_chart.TsdaChart('Class Attendance Weekly Report', 'Week', 'Attendance%')
X,Y = reporting.services.simulator.tsda_sim.TsdaSimulator(100, 3600).generate()
chart.set_data(x=X, y=Y)
chart.plot()
