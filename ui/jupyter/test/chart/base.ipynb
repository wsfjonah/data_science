# %%
import reporting.services.chart.base_chart as base_chart
import reporting.services.simulator.base_sim as base_sim

chart = base_chart.BaseChart('Data Chart', 'X bar', 'Y bar')
X,Y = base_sim.BaseSimulator(30).generate()
chart.set_data(x=X, y=Y)
chart.plot()
