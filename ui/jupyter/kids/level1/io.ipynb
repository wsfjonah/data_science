# %%
# import
import level1

# %% [markdown]
# # 概述
#
# 计算机的五大组成部分为：运算器，控制器，存储器，输入，输出。该应用将依照计算机以及计算程序的基本结构，介绍计算机编程的基本知识，包括：
#
# 1. 简单的输入、输出
# 1. 看见数据
# 1. 不同的输入
# 1. 什么是逻辑判断
# 1. 简单的自动化
# 1. 函数
# 1. 递推

# %% [markdown]
# ## 组成
# 该应用中的每个程序分为3大组成：
# 1. 输入（Input）
# 1. 处理（Process）
# 1. 输出（Output）

# %% [markdown]
# # 简单的输入输出

# %% [markdown]
# ## Question
# 班里有6个小朋友，Mat、Jane、Philip、Chloe、Kate、Joel，老师每天给他们准备总共60个小饼干做为课间的零食。

# %%
# These are setup code:
project = level1.FriendsCookieProj()

# %% [markdown]
# ## Input

# %%
project.add_friends(['Mat','Jane','Philip','Chloe','Kate','Joel'])

# TODO: add number of cookies corresponding to the friends' name above
project.add_cookies([])

# %% [markdown]
# ## Process

# %%
print('nothing to do')
# Out:
# nothing to do

# %% [markdown]
# ## Output

# %%
project.get_output().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="514e419530c14ca69818f4192393ae01" style="width:900px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_514e419530c14ca69818f4192393ae01 = echarts.init(
#             document.getElementById('514e419530c14ca69818f4192393ae01'), 'white', {renderer: 'canvas'});
#         var option_514e419530c14ca69818f4192393ae01 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Cookies",
#             "data": [],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Cookies"
#             ],
#             "selected": {
#                 "Cookies": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "Name",
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mat",
#                 "Jane",
#                 "Philip",
#                 "Chloe",
#                 "Kate",
#                 "Joel"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Cookies",
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Data Chart"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     },
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 0,
#         "end": 100,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_514e419530c14ca69818f4192393ae01.setOption(option_514e419530c14ca69818f4192393ae01);
#     });
# </script>

# %% [markdown]
# # 输入的改变
#
# ## Question
# 继上面的问题，现在老师多了10个小饼干，根据小朋友在课堂的表现奖励给小朋友，其中Mat得到1个，Jane得到3个，Philip得到1个，Kate得到1个，Joel得到4个。

# %%
# These are setup code:
project = level1.FriendsCookieProj()

# %% [markdown]
# ## Input

# %%
project.add_friends(['Mat','Jane','Philip','Chloe','Kate','Joel'])

# TODO: modify number of cookies corresponding to the friends' name above
project.add_cookies([])

# %% [markdown]
# ## Process

# %%
print('nothing to do')
# Out:
# nothing to do

# %% [markdown]
# ## Output

# %%
project.get_output().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8ab9278519ce48378dd2d3b918611e9f" style="width:900px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8ab9278519ce48378dd2d3b918611e9f = echarts.init(
#             document.getElementById('8ab9278519ce48378dd2d3b918611e9f'), 'white', {renderer: 'canvas'});
#         var option_8ab9278519ce48378dd2d3b918611e9f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Cookies",
#             "data": [],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Cookies",
#             "data": [],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Cookies",
#                 "Cookies"
#             ],
#             "selected": {
#                 "Cookies": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "Name",
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mat",
#                 "Jane",
#                 "Philip",
#                 "Chloe",
#                 "Kate",
#                 "Joel"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Cookies",
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Data Chart"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     },
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 0,
#         "end": 100,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_8ab9278519ce48378dd2d3b918611e9f.setOption(option_8ab9278519ce48378dd2d3b918611e9f);
#     });
# </script>
